# %% [markdown]
# ## Oxford-IIIT Pet Dataset 준비
#
# - dataset은 아래 주소에서 받으실 수 있습니다
# https://drive.google.com/file/d/1dIR9ANjUsV9dWa0pS9J0c2KUGMfpIRG0/view?usp=sharing
#
# - 원본 data는 아래 경로에서 받을 수 있습니다.
# https://www.robots.ox.ac.uk/~vgg/data/pets/
#
# 이 dataset은 고양이와 개 총 37종류의 image(class별 약 200장)와 각 image에 대한 class정보, 머리 위치에 대한 Bounding box 정보, 그리고 image segmentation map과 몇가지 추가 정보로 구성되어 있습니다.
#
# 이 실습에서는 dataset을 다운받고 google drive에 upload한 이후에 개에 대한 data만 따로 모아서 localization 및 segmentation을 학습시키기 위한 data 준비 과정에 대해 진행합니다.

# %% [markdown]
# #### 실습 directory(TensorFlow_Training_13th) 아래에 oxford_pet 이라는 이름의 directory를 만들고 다운받은 dataset을 upload합니다
#
# oxford_pet.zip 파일을 upload 합니다
#
# upload가 완료된 이후 아래 code를 수행합니다

# %%
## google drive 연동 확인
from google.colab import drive
import os
if not os.path.exists('/content/gdrive'):
    drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
## data가 저장된 directory로 이동
cd '/content/gdrive/My Drive/TensorFlow_Training_13th/oxford_pet'
# Out:
# /content/gdrive/My Drive/TensorFlow_Training_13th/oxford_pet

# %%
## oxford_pet.zip 파일이 보이는지 확인
# !ls
# Out:
# oxford_pet.zip

# %%
## 압축풀기
# !unzip oxford_pet.zip
# Out:
# Archive:  oxford_pet.zip
#   inflating: annotations/._trimaps
#   inflating: annotations/list.txt
#   inflating: annotations/README
#   inflating: annotations/test.txt
#   inflating: annotations/trainval.txt
#   inflating: annotations/trimaps/Abyssinian_1.png
#   inflating: annotations/trimaps/Abyssinian_10.png
#   inflating: annotations/trimaps/Abyssinian_100.png
#   inflating: annotations/trimaps/Abyssinian_101.png
#   inflating: annotations/trimaps/Abyssinian_102.png
#   inflating: annotations/trimaps/Abyssinian_103.png
#   inflating: annotations/trimaps/Abyssinian_104.png
#   inflating: annotations/trimaps/Abyssinian_105.png
#   inflating: annotations/trimaps/Abyssinian_106.png
#   inflating: annotations/trimaps/Abyssinian_107.png
#   inflating: annotations/trimaps/Abyssinian_108.png
#   inflating: annotations/trimaps/Abyssinian_109.png
#   inflating: annotations/trimaps/Abyssinian_11.png
#   inflating: annotations/trimaps/Abyssinian_110.png
# ...
